# %%
#Leave off here. 
import numpy as np
import matplotlib.pyplot as plt

# Data
categories = ['RF ICDs', 'RF CPTs', 'RF Keywords', 'RF All Combined','LR ICDs', 'LR CPTs', 'LR Keywords', 'LR All Combined' ]
auroc = [0.915, 0.719, 0.985, 0.979, 0.915, 0.721, 0.979, ]
auprc = [0.6595, 0.4810, 0.9327, 0.8961]
recall = [0.9507, 0.6203, 0.9739, 0.8406]
f1_score = [0.7558, 0.4477, 0.8842, 0.8555]

# Bar width
bar_width = 0.2

# Set positions of bars on X-axis
r1 = np.arange(len(categories))
r2 = [x + bar_width for x in r1]
r3 = [x + bar_width for x in r2]
r4 = [x + bar_width for x in r3]

# Define shades of blue
auroc_color = '#a6cee3'  # Light blue
auprc_color = '#1f77b4'  # Base blue
recall_color = '#004b87'  # Dark blue
f1_score_color = '#003f5c'  # Darker blue

# Create the bar plot
plt.figure(figsize=(12, 7))

bars_auroc = plt.bar(r1, auroc, color=auroc_color, width=bar_width, edgecolor='grey', label='AUROC')
bars_auprc = plt.bar(r2, auprc, color=auprc_color, width=bar_width, edgecolor='grey', label='AUPRC')
bars_recall = plt.bar(r3, recall, color=recall_color, width=bar_width, edgecolor='grey', label='Recall')
bars_f1_score = plt.bar(r4, f1_score, color=f1_score_color, width=bar_width, edgecolor='grey', label='F1 Score')

# Add values on top of the bars
def add_values(bars):
    for bar in bars:
        height = bar.get_height()
        plt.text(bar.get_x() + bar.get_width() / 2, height, f'{height:.2f}', ha='center', va='bottom')

add_values(bars_auroc)
add_values(bars_auprc)
add_values(bars_recall)
add_values(bars_f1_score)

# Add xticks on the middle of the group bars with category names
plt.xticks([r + bar_width*1.5 for r in range(len(categories))], categories)

# Hide the x-axis label "Categories"
plt.xlabel('')  # Empty string to hide the x-axis label

# Create the legend with a larger font size
plt.legend(fontsize=12, loc='upper center', bbox_to_anchor=(0.5, -0.15), ncol=4, frameon=False)

plt.title('Performance Metrics Comparison')
plt.tight_layout()
plt.show()
# Out:
# Running cells with 'Python 3.8.2' requires the ipykernel package.
#
# Run the following command to install 'ipykernel' into the Python environment.
#
# Command: '/usr/bin/python3 -m pip install ipykernel -U --user --force-reinstall'

# %%
import numpy as np
import matplotlib.pyplot as plt

# Updated Data
categories = ['RF All Combined', 'RF Keywords Only', 'RF CPT Codes Only', 'RF ICD Codes Only', 
              'LR All Combined', 'LR Keywords Only', 'LR CPT Codes Only', 'LR ICD Codes Only']

auroc = [0.979, 0.985, 0.719, 0.915, 0.977, 0.979, 0.721, 0.915]
auprc = [0.896, 0.944, 0.481, 0.660, 0.902, 0.906, 0.462, 0.666]
recall = [0.841, 0.971, 0.620, 0.986, 0.959, 0.977, 0.725, 0.959]
f1_score = [0.856, 0.890, 0.448, 0.761, 0.862, 0.892, 0.484, 0.751]

# Bar width
bar_width = 0.2

# Set positions of bars on X-axis
r1 = np.arange(len(categories))
r2 = [x + bar_width for x in r1]
r3 = [x + bar_width for x in r2]
r4 = [x + bar_width for x in r3]

# Define shades of blue
auroc_color = '#a6cee3'  # Light blue
auprc_color = '#1f77b4'  # Base blue
recall_color = '#004b87'  # Dark blue
f1_score_color = '#003f5c'  # Darker blue

# Create the bar plot
plt.figure(figsize=(14, 8))

bars_auroc = plt.bar(r1, auroc, color=auroc_color, width=bar_width, edgecolor='grey', label='AUROC')
bars_auprc = plt.bar(r2, auprc, color=auprc_color, width=bar_width, edgecolor='grey', label='AUPRC')
bars_recall = plt.bar(r3, recall, color=recall_color, width=bar_width, edgecolor='grey', label='Recall')
bars_f1_score = plt.bar(r4, f1_score, color=f1_score_color, width=bar_width, edgecolor='grey', label='F1 Score')

# Add values on top of the bars
def add_values(bars):
    for bar in bars:
        height = bar.get_height()
        plt.text(bar.get_x() + bar.get_width() / 2, height, f'{height:.3f}', ha='center', va='bottom')

add_values(bars_auroc)
add_values(bars_auprc)
add_values(bars_recall)
add_values(bars_f1_score)

# Add xticks on the middle of the group bars with category names
plt.xticks([r + bar_width*1.5 for r in range(len(categories))], categories, rotation=45, ha='right')

# Hide the x-axis label "Categories"
plt.xlabel('')  # Empty string to hide the x-axis label

# Create the legend with a larger font size
plt.legend(fontsize=12, loc='upper center', bbox_to_anchor=(0.5, -0.15), ncol=4, frameon=False)

plt.title('Performance Metrics Comparison')
plt.tight_layout()
plt.show()
# Out:
# Running cells with 'Python 3.8.2' requires the ipykernel package.
#
# Run the following command to install 'ipykernel' into the Python environment.
#
# Command: '/usr/bin/python3 -m pip install ipykernel -U --user --force-reinstall'

# %%
# Data
categories = ['ICDs', 'CPTs', 'Keywords', 'All Combined']
auroc = [0.9152, 0.7188, 0.9829, 0.9791]
auprc = [0.6595, 0.4810, 0.9327, 0.8961]
recall = [0.9507, 0.6203, 0.9739, 0.8406]
f1_score = [0.7558, 0.4477, 0.8842, 0.8555]

# Bar width
bar_width = 0.2

# Set positions of bars on X-axis
r1 = np.arange(len(categories))
r2 = [x + bar_width for x in r1]
r3 = [x + bar_width for x in r2]
r4 = [x + bar_width for x in r3]

# Define shades of maroon
auroc_color = '#d64d4d'  # Light maroon
auprc_color = '#c0392b'  # Base maroon
recall_color = '#a63d40'  # Darker maroon
f1_score_color = '#6d2b2a'  # Darkest maroon


# Create the bar plot
plt.figure(figsize=(12, 7))

bars_auroc = plt.bar(r1, auroc, color=auroc_color, width=bar_width, edgecolor='grey', label='AUROC')
bars_auprc = plt.bar(r2, auprc, color=auprc_color, width=bar_width, edgecolor='grey', label='AUPRC')
bars_recall = plt.bar(r3, recall, color=recall_color, width=bar_width, edgecolor='grey', label='Recall')
bars_f1_score = plt.bar(r4, f1_score, color=f1_score_color, width=bar_width, edgecolor='grey', label='F1 Score')

# Add values on top of the bars
def add_values(bars):
    for bar in bars:
        height = bar.get_height()
        plt.text(bar.get_x() + bar.get_width() / 2, height, f'{height:.2f}', ha='center', va='bottom')

add_values(bars_auroc)
add_values(bars_auprc)
add_values(bars_recall)
add_values(bars_f1_score)

# Add xticks on the middle of the group bars with category names
plt.xticks([r + bar_width*1.5 for r in range(len(categories))], categories)

# Hide the x-axis label "Categories"
plt.xlabel('')  # Empty string to hide the x-axis label

# Create the legend with a larger font size
plt.legend(fontsize=12, loc='upper center', bbox_to_anchor=(0.5, -0.15), ncol=4, frameon=False)

plt.title('Performance Metrics Comparison')
plt.tight_layout()
plt.show()

# %%
#RF code
import numpy as np
import matplotlib.pyplot as plt

# Data for RF models
categories = ['All Combined', 'Keywords Only', 'CPT Codes Only', 'ICD Codes Only']
auroc = [0.979, 0.985, 0.719, 0.915]
auprc = [0.896, 0.944, 0.481, 0.660]
recall = [0.841, 0.971, 0.620, 0.986]
f1_score = [0.856, 0.890, 0.448, 0.761]

# Confidence intervals for RF models
auroc_ci = [(0.973, 0.985), (0.981, 0.990), (0.692, 0.743), (0.902, 0.929)]
auprc_ci = [(0.851, 0.934), (0.924, 0.962), (0.438, 0.520), (0.602, 0.717)]
recall_ci = [(0.804, 0.876), (0.951, 0.987), (0.569, 0.668), (0.971, 0.997)]
f1_score_ci = [(0.827, 0.881), (0.865, 0.913), (0.406, 0.486), (0.727, 0.793)]

# Calculate error bars
auroc_err = [((high - low) / 2) for low, high in auroc_ci]
auprc_err = [((high - low) / 2) for low, high in auprc_ci]
recall_err = [((high - low) / 2) for low, high in recall_ci]
f1_score_err = [((high - low) / 2) for low, high in f1_score_ci]

# Bar width
bar_width = 0.2

# Set positions of bars on X-axis
r1 = np.arange(len(categories))
r2 = [x + bar_width for x in r1]
r3 = [x + bar_width for x in r2]
r4 = [x + bar_width for x in r3]

# Define shades of blue
auroc_color = '#a6cee3'  # Light blue
auprc_color = '#1f77b4'  # Base blue
recall_color = '#004b87'  # Dark blue
f1_score_color = '#003f5c'  # Darker blue

# Create the bar plot for RF models
plt.figure(figsize=(12, 7))

bars_auroc = plt.bar(r1, auroc, yerr=auroc_err, color=auroc_color, width=bar_width, edgecolor='grey', label='AUROC', capsize=5)
bars_auprc = plt.bar(r2, auprc, yerr=auprc_err, color=auprc_color, width=bar_width, edgecolor='grey', label='AUPRC', capsize=5)
bars_recall = plt.bar(r3, recall, yerr=recall_err, color=recall_color, width=bar_width, edgecolor='grey', label='Recall', capsize=5)
bars_f1_score = plt.bar(r4, f1_score, yerr=f1_score_err, color=f1_score_color, width=bar_width, edgecolor='grey', label='F1 Score', capsize=5)

# Add values on top of the bars
def add_values(bars):
    for bar in bars:
        height = bar.get_height()
        plt.text(bar.get_x() + bar.get_width() / 2, height, f'{height:.3f}', ha='center', va='bottom')

add_values(bars_auroc)
add_values(bars_auprc)
add_values(bars_recall)
add_values(bars_f1_score)

# Add xticks on the middle of the group bars with category names
plt.xticks([r + bar_width*1.5 for r in range(len(categories))], categories)

# Hide the x-axis label "Categories"
plt.xlabel('')  # Empty string to hide the x-axis label

# Create the legend with a larger font size
plt.legend(fontsize=12, loc='upper center', bbox_to_anchor=(0.5, -0.15), ncol=4, frameon=False)

plt.title('Performance Metrics Comparison for RF Models')
plt.tight_layout()
plt.show()
# Out:
# Running cells with 'Python 3.8.2' requires the ipykernel package.
#
# Run the following command to install 'ipykernel' into the Python environment.
#
# Command: '/usr/bin/python3 -m pip install ipykernel -U --user --force-reinstall'

# %%
#LR Code
import numpy as np
import matplotlib.pyplot as plt

# Data for LR models
categories = ['All Combined', 'Keywords Only', 'CPT Codes Only', 'ICD Codes Only']
auroc = [0.977, 0.979, 0.721, 0.915]
auprc = [0.902, 0.906, 0.462, 0.666]
recall = [0.959, 0.977, 0.725, 0.959]
f1_score = [0.862, 0.892, 0.484, 0.751]

# Confidence intervals for LR models
auroc_ci = [(0.970, 0.984), (0.973, 0.985), (0.697, 0.744), (0.901, 0.929)]
auprc_ci = [(0.864, 0.933), (0.872, 0.936), (0.418, 0.501), (0.608, 0.721)]
recall_ci = [(0.938, 0.980), (0.961, 0.992), (0.674, 0.775), (0.934, 0.979)]
f1_score_ci = [(0.834, 0.886), (0.867, 0.914), (0.445, 0.518), (0.719, 0.781)]

# Calculate error bars
auroc_err = [((high - low) / 2) for low, high in auroc_ci]
auprc_err = [((high - low) / 2) for low, high in auprc_ci]
recall_err = [((high - low) / 2) for low, high in recall_ci]
f1_score_err = [((high - low) / 2) for low, high in f1_score_ci]

# Bar width
bar_width = 0.2

# Set positions of bars on X-axis
r1 = np.arange(len(categories))
r2 = [x + bar_width for x in r1]
r3 = [x + bar_width for x in r2]
r4 = [x + bar_width for x in r3]

# Define shades of blue
auroc_color = '#a6cee3'  # Light blue
auprc_color = '#1f77b4'  # Base blue
recall_color = '#004b87'  # Dark blue
f1_score_color = '#003f5c'  # Darker blue

# Create the bar plot for LR models
plt.figure(figsize=(12, 7))

bars_auroc = plt.bar(r1, auroc, yerr=auroc_err, color=auroc_color, width=bar_width, edgecolor='grey', label='AUROC', capsize=5)
bars_auprc = plt.bar(r2, auprc, yerr=auprc_err, color=auprc_color, width=bar_width, edgecolor='grey', label='AUPRC', capsize=5)
bars_recall = plt.bar(r3, recall, yerr=recall_err, color=recall_color, width=bar_width, edgecolor='grey', label='Recall', capsize=5)
bars_f1_score = plt.bar(r4, f1_score, yerr=f1_score_err, color=f1_score_color, width=bar_width, edgecolor='grey', label='F1 Score', capsize=5)

# Add values on top of the bars
def add_values(bars):
    for bar in bars:
        height = bar.get_height()
        plt.text(bar.get_x() + bar.get_width() / 2, height, f'{height:.3f}', ha='center', va='bottom')

add_values(bars_auroc)
add_values(bars_auprc)
add_values(bars_recall)
add_values(bars_f1_score)

# Add xticks on the middle of the group bars with category names
plt.xticks([r + bar_width*1.5 for r in range(len(categories))], categories)

# Hide the x-axis label "Categories"
plt.xlabel('')  # Empty string to hide the x-axis label

# Create the legend with a larger font size
plt.legend(fontsize=12, loc='upper center', bbox_to_anchor=(0.5, -0.15), ncol=4, frameon=False)

plt.title('Performance Metrics Comparison for LR Models')
plt.tight_layout()
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

# Data
categories = ['ICDs', 'CPTs', 'Keywords', 'All Combined']
auroc = [0.9152, 0.7188, 0.9829, 0.9791]
auprc = [0.6595, 0.4810, 0.9327, 0.8961]
recall = [0.9507, 0.6203, 0.9739, 0.8406]
f1_score = [0.7558, 0.4477, 0.8842, 0.8555]

# Prepare data for the table
table_data = [auroc, auprc, recall, f1_score]
column_labels = ['ICDs', 'CPTs', 'Keywords', 'All Combined']
row_labels = ['AUROC', 'AUPRC', 'Recall', 'F1 Score']
cell_text = np.array(table_data).tolist()

# Create the figure and axis
plt.figure(figsize=(12, 6))

# Create the table
plt.table(cellText=cell_text,
          rowLabels=row_labels,
          colLabels=column_labels,
          cellLoc='center',
          loc='center',
          bbox=[0, 0, 1, 1])  # Adjust bbox for positioning

plt.title('Performance Metrics Table')
plt.axis('off')  # Hide the axis

plt.tight_layout()
plt.show()
